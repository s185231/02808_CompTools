# %%
# load first n rows of data
import pandas as pd
books_data = pd.read_csv('data/books_data.csv')
books_ratings = pd.read_csv('data/books_rating.csv')

# Remove all rows that contain missing values
#books_data = books_data.dropna()
#books_ratings = books_ratings.dropna()

# %%
print(books_data.head())
print(books_ratings.head())

# print length of data
print("The number of entries in books_data is:", len(books_data))
print("The number of entries in books_ratings is:", len(books_ratings))

# print names of columns
books_data_cols = list(books_data.columns)
books_ratings_cols = list(books_ratings.columns)

# find number of unique users
print("There are", len(books_ratings['User_id'].unique()), "unique users in the dataset")
# Out:
#                                                 Title  \
# 5   The Church of Christ: A Biblical Ecclesiology ...
# 31  Voices from the Farm: Adventures in Community ...
# 33                            The Battleship Bismarck
# 42                            Tess and the Highlander
# 43   Beginner's Yoruba (Hippocrene Beginner's Series)
#
#                                           description  \
# 5   In The Church of Christ: A Biblical Ecclesiolo...
# 31  Twenty-five years ago, at the height of the co...
# 33  The Bismarck is perhaps the most famous – and ...
# 42  In 1543, on a windswept isle off of Scotland, ...
# 43  "Beginner's Yoruba" is now available with two ...
#
#                     authors  \
# 5      ['Everett Ferguson']
# 31          ['Rupert Fike']
# 33     ['Stefan Draminski']
# 42       ['May Mcgoldrick']
# 43  ['Kayode J. Fakinlede']
#
#                                                 image  \
# 5   http://books.google.com/books/content?id=kVqRa...
# ...

# %%
# Print column names
print(books_data_cols)
print(books_ratings_cols)

# Count the number of occurrences of each user
user_counts = list(books_ratings['User_id'].value_counts())
print(user_counts)

# find number of unique books
books_counts = list(books_ratings['Title'].value_counts())
print(books_counts)

author_counts = list(books_data['authors'].value_counts())
print(author_counts)

print(books_ratings['review/helpfulness'])
# Out:
# ['Title', 'description', 'authors', 'image', 'previewLink', 'publisher', 'publishedDate', 'infoLink', 'categories', 'ratingsCount']
# ['Id', 'Title', 'Price', 'User_id', 'profileName', 'review/helpfulness', 'review/score', 'review/time', 'review/summary', 'review/text']
# ...
